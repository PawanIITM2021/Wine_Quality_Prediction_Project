# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


from warnings import filterwarnings
filterwarnings(action = 'ignore')

# %% [markdown]
# # Loading Dataset

# %%
wine = pd.read_csv("C:/Users/91790/Desktop/Corizo Internship/Internship_Project/Wine_Quality_Analysis/Red_wine.csv")
wine.sample(25)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 120             7.3             1.070         0.09             1.7      0.178
# 1244            5.9             0.290         0.25            13.4      0.067
# 723             7.1             0.310         0.30             2.2      0.053
# 201             8.8             0.370         0.48             2.1      0.097
# 756             6.3             0.980         0.01             2.0      0.057
# 1557            6.6             0.855         0.02             2.4      0.062
# 943             9.8             0.500         0.34             2.3      0.094
# 1132            7.4             0.360         0.34             1.8      0.075
# 883             7.2             0.600         0.04             2.5      0.076
# 589            10.2             0.290         0.49             2.6      0.059
# 759             8.8             0.420         0.21             2.5      0.092
# 110             7.8             0.560         0.19             1.8      0.104
# 106             7.8             0.410         0.68             1.7      0.467
# 151             9.2             0.520         1.00             3.4      0.610
# 595             8.9             0.595         0.41             7.9      0.086
# 628             8.7             0.540         0.26             2.5      0.097
# 881             7.6             0.715         0.00             2.1      0.068
# 760             9.0             0.580         0.25             2.8      0.075
# 1135            8.0             0.250         0.43             1.7      0.067
# 947             8.3             0.280         0.48             2.1      0.093
# 1174            7.6             0.360         0.31             1.7      0.079
# 575            12.3             0.270         0.49             3.1      0.079
# 858            11.7             0.280         0.47             1.7      0.054
# 933             7.4             0.610         0.01             2.0      0.074
# 1403            7.2             0.330         0.33             1.7      0.061
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 120                  10.0                  89.0  0.99620  3.30       0.57
# 1244                 72.0                 160.0  0.99721  3.52       0.54
# 723                  36.0                 127.0  0.99650  3.52       1.62
# 201                  39.0                 145.0  0.99750  3.52       1.03
# 756                  15.0                  33.0  0.99488  3.52       0.46
# 1557                 15.0                  23.0  0.99627  3.52       0.60
# 943                  10.0                  45.0  0.99864  3.52       0.60
# 1132                 18.0                  38.0  0.99330  3.52       0.88
# 883                  18.0                  88.0  0.99745  3.52       0.55
# 589                   5.0                  13.0  0.99760  3.52       0.74
# 759                  33.0                  88.0  0.99823  3.52       0.52
# 110                  12.0                  47.0  0.99640  3.19       0.93
# 106                  18.0                  69.0  0.99730  3.08       1.31
# 151                  32.0                  69.0  0.99960  2.74       2.00
# 595                  30.0                 109.0  0.99980  3.52       0.57
# 628                   7.0                  31.0  0.99760  3.52       0.60
# 881                  30.0                  35.0  0.99533  3.52       0.65
# 760                   9.0                 104.0  0.99779  3.52       0.57
# 1135                 22.0                  50.0  0.99460  3.52       0.60
# 947                   6.0                  12.0  0.99408  3.52       0.62
# 1174                 26.0                  65.0  0.99716  3.52       0.62
# 575                  28.0                  46.0  0.99930  3.52       0.80
# 858                  17.0                  32.0  0.99686  3.52       0.67
# 933                  13.0                  38.0  0.99748  3.52       0.65
# 1403                  3.0                  13.0  0.99600  3.52       1.10
#
#       alcohol  quality
# 120       9.0      5.0
# 1244     10.3      6.0
# 723       9.5      5.0
# 201       9.3      5.0
# 756      11.2      6.0
# 1557     11.0      6.0
# 943       9.7      7.0
# 1132     13.6      7.0
# 883       9.5      5.0
# 589      10.5      7.0
# 759       9.2      5.0
# 110       9.5      5.0
# 106       9.3      5.0
# 151       9.4      4.0
# 595       9.3      5.0
# 628       9.3      6.0
# 881      11.4      6.0
# 760       9.7      5.0
# 1135     11.9      6.0
# 947      12.4      7.0
# 1174      9.5      6.0
# 575      10.2      6.0
# 858      10.6      7.0
# 933       9.8      5.0
# 1403     10.0      8.0

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1598 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# # Description

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1598.000000  1599.000000
# mean      0.087467            15.874922             46.433041     0.996747
# std       0.047065            10.460157             32.876249     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1598.000000  1599.000000  1599.000000  1598.000000
# mean      3.498586     0.658149    10.422983     5.636421
# std       0.080346     0.169507     1.065668     0.807665
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.520000     0.550000     9.500000     5.000000
# 50%       3.520000     0.620000    10.200000     6.000000
# 75%       3.520000     0.730000    11.100000     6.000000
# max       3.900000     2.000000    14.900000     8.000000

# %% [markdown]
# # Finding Null Values

# %%
print(wine.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    1
# density                 0
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
wine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3.0           8.360000          0.884500     0.171000        2.635000
# 4.0           7.779245          0.693962     0.174151        2.694340
# 5.0           8.167500          0.576846     0.244044        2.528750
# 6.0           8.347179          0.497484     0.273824        2.477194
# 7.0           8.872362          0.403920     0.375176        2.720603
# 8.0           8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3.0       0.122500            11.000000             24.900000  0.997464
# 4.0       0.090679            12.264151             36.245283  0.996542
# 5.0       0.092754            16.992647             56.480118  0.997103
# 6.0       0.084956            15.711599             40.869906  0.996615
# 7.0       0.076588            14.045226             35.020101  0.996104
# 8.0       0.068444            13.277778             33.444444  0.995212
#
#                pH  sulphates    alcohol
# quality
# 3.0      3.520000   0.570000   9.955000
# 4.0      3.485660   0.596415  10.265094
# 5.0      3.485147   0.621103   9.900294
# 6.0      3.508100   0.675329  10.629519
# 7.0      3.514774   0.741256  11.465913
# 8.0      3.520000   0.767778  12.094444

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Countplot:

# %%
sns.countplot(wine['quality'])
plt.show()

# %%
wine.plot(kind = 'box', subplots = True, layout = (4,4), sharex = False)
# Out:
# fixed acidity               AxesSubplot(0.125,0.71587;0.168478x0.16413)
# volatile acidity         AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# citric acid              AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# residual sugar           AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# chlorides                  AxesSubplot(0.125,0.518913;0.168478x0.16413)
# free sulfur dioxide     AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# total sulfur dioxide    AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# density                 AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# pH                         AxesSubplot(0.125,0.321957;0.168478x0.16413)
# sulphates               AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# alcohol                 AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# quality                 AxesSubplot(0.731522,0.321957;0.168478x0.16413)
# dtype: object

# %%
wine['fixed acidity'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histogram

# %%
wine.hist(figsize=(10,10), bins = 50)
plt.show()

# %% [markdown]
# # Feature Selection

# %%
wine.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1490            7.1              0.22         0.49             1.8      0.039
# 1560            7.8              0.60         0.26             2.0      0.080
# 1131            5.9              0.19         0.21             1.7      0.045
# 1325            6.7              0.46         0.24             1.7      0.077
# 8               7.8              0.58         0.02             2.0      0.073
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1490                  8.0                  18.0  0.99344  3.52       0.56
# 1560                 31.0                 131.0  0.99622  3.52       0.52
# 1131                 57.0                 135.0  0.99341  3.52       0.44
# 1325                 18.0                  34.0  0.99480  3.52       0.60
# 8                     9.0                  18.0  0.99680  3.36       0.57
#
#       alcohol  quality
# 1490     12.4      6.0
# 1560      9.9      5.0
# 1131      9.5      5.0
# 1325     10.6      6.0
# 8         9.5      7.0

# %%
wine['quality'].unique()
# Out:
# array([ 5.,  6.,  7.,  4., nan,  8.,  3.])

# %%
# If wine quality is 7 or above then will consider as good quality wine
wine['goodquality'] = [1 if x >= 7 else 0 for x in wine['quality']]
wine.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1400            7.9             0.690         0.21             2.1      0.080
# 478             9.6             0.680         0.24             2.2      0.087
# 217             8.1             0.725         0.22             2.2      0.072
# 1165            8.5             0.440         0.50             1.9      0.369
# 920             9.6             0.410         0.37             2.3      0.091
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1400                 33.0                 141.0  0.99620  3.52       0.51
# 478                   5.0                  28.0  0.99880  3.52       0.60
# 217                  11.0                  41.0  0.99670  3.52       0.55
# 1165                 15.0                  38.0  0.99634  3.52       1.10
# 920                  10.0                  23.0  0.99786  3.52       0.56
#
#       alcohol  quality  goodquality
# 1400      9.9      5.0            0
# 478      10.2      5.0            0
# 217       9.1      5.0            0
# 1165      9.4      5.0            0
# 920      10.5      5.0            0

# %%
 x = wine.drop(['quality','goodquality'], axis = 1)
 y = wine.sample(5)

# %%
wine['goodquality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
#  Separate dependent and independent variables
x = wine.drop(['quality','goodquality'], axis = 1)
y = wine['goodquality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.52       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.52       0.75
# 1597                 32.0                  44.0  0.99547  3.52       0.71
# 1598                 18.0                  42.0  0.99549  3.52       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: goodquality, Length: 1599, dtype: int64

# %% [markdown]
# # Feature Importance

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\91790\anaconda3\lib\site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\91790\anaconda3\lib\site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\91790\anaconda3\lib\site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\91790\anaconda3\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\91790\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Collecting numpy<2.0,>=1.17.3 (from scikit-learn)
#   Using cached numpy-1.22.4-cp38-cp38-win_amd64.whl (14.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed numpy-1.22.4
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\91790\anaconda3\lib\site-packages (1.22.4)
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/69/65/0d47953afa0ad569d12de5f65d964321c208492064c38fe3b0b9744f8d44/numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed numpy-1.24.4
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.4 which is incompatible.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.24.4 which is incompatible.

# %%
from sklearn.ensemble import ExtraTreesClassifier
classifiern = ExtraTreesClassifier()
classifiern.fit(x,y)
score = classifiern.features_importances_
print(score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15176/3985486869.py in <module>
#       1 from sklearn.ensemble import ExtraTreesClassifier
#       2 classifiern = ExtraTreesClassifier()
# ----> 3 classifiern.fit(x,y)
#       4 score = classifiern.features_importances_
#       5 print(score)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302         indicators = Parallel(
#     303             n_jobs=self.n_jobs,
# --> 304             verbose=self.verbose,
#     305             prefer="threads",
#     306         )(
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431             Whether to reset the `feature_names_in_` attribute.
#     432             If False, the input will be checked for consistency with
# --> 433             feature names of data provided when reset was last True.
#     434             .. note::
#     435                It is recommended to call `reset=True` in `fit` and in the first
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869                     unique_dtypes = set([dt.subtype.name for dt in array_orig.dtypes])
#     870                     if len(unique_dtypes) > 1:
# --> 871                         raise ValueError(
#     872                             "Pandas DataFrame with mixed sparse extension arrays "
#     873                             "generated a sparse matrix with object dtype which "
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718         Whether to raise a value error if array is not 2D.
#     719
# --> 720     allow_nd : bool, default=False
#     721         Whether to allow array.ndim > 2.
#     722
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101
#     102     X = xp.asarray(X)
# --> 103
#     104     # for object dtype data, we only check for NaNs (GH-13254)
#     105     if X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %% [markdown]
# # Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state = 7)

# %% [markdown]
# # Result

# %%
model_res = pd.DataFrame(columns = ['Model','score'])

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
# accuracy_score(Y_test, Y_pred)
model_res.loc[len(model_res)] = ['LogisticRegression', accuracy_score(y_test, y_pred)]
model_res

# %% [markdown]
# # Using KNN:

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['KNeighboursClassifier', accuracy_score(y_test, y_pred)]
model_res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15176/2034322991.py in <module>
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 model = KNeighborsClassifier(n_neighbors=3)
# ----> 3 model.fit(x_train, y_train)
#       4 y_pred = model.predict(x_test)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     177     [0]
#     178     >>> print(neigh.predict_proba([[0.9]]))
# --> 179     [[0.666... 0.333...]]
#     180     """
#     181
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     361         if return_distance:
#     362             data = np.compress(mask, graph.data)
# --> 363         indices = np.compress(mask, graph.indices)
#     364         indptr = np.concatenate(([0], np.cumsum(mask)))[graph.indptr]
#     365
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431             Whether to reset the `feature_names_in_` attribute.
#     432             If False, the input will be checked for consistency with
# --> 433             feature names of data provided when reset was last True.
#     434             .. note::
#     435                It is recommended to call `reset=True` in `fit` and in the first
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869                     unique_dtypes = set([dt.subtype.name for dt in array_orig.dtypes])
#     870                     if len(unique_dtypes) > 1:
# --> 871                         raise ValueError(
#     872                             "Pandas DataFrame with mixed sparse extension arrays "
#     873                             "generated a sparse matrix with object dtype which "
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718         Whether to raise a value error if array is not 2D.
#     719
# --> 720     allow_nd : bool, default=False
#     721         Whether to allow array.ndim > 2.
#     722
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101
#     102     X = xp.asarray(X)
# --> 103
#     104     # for object dtype data, we only check for NaNs (GH-13254)
#     105     if X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['KNeighborsClassifier', accuracy_score(y_test,y_pred)]
model_res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15176/514305112.py in <module>
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 model = KNeighborsClassifier(n_neighbors=3)
# ----> 3 model.fit(x_train, y_train)
#       4 y_pred = model.predict(x_test)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     177     [0]
#     178     >>> print(neigh.predict_proba([[0.9]]))
# --> 179     [[0.666... 0.333...]]
#     180     """
#     181
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     361         if return_distance:
#     362             data = np.compress(mask, graph.data)
# --> 363         indices = np.compress(mask, graph.indices)
#     364         indptr = np.concatenate(([0], np.cumsum(mask)))[graph.indptr]
#     365
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431             Whether to reset the `feature_names_in_` attribute.
#     432             If False, the input will be checked for consistency with
# --> 433             feature names of data provided when reset was last True.
#     434             .. note::
#     435                It is recommended to call `reset=True` in `fit` and in the first
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869                     unique_dtypes = set([dt.subtype.name for dt in array_orig.dtypes])
#     870                     if len(unique_dtypes) > 1:
# --> 871                         raise ValueError(
#     872                             "Pandas DataFrame with mixed sparse extension arrays "
#     873                             "generated a sparse matrix with object dtype which "
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718         Whether to raise a value error if array is not 2D.
#     719
# --> 720     allow_nd : bool, default=False
#     721         Whether to allow array.ndim > 2.
#     722
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101
#     102     X = xp.asarray(X)
# --> 103
#     104     # for object dtype data, we only check for NaNs (GH-13254)
#     105     if X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# ### using SVC:

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:", accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['SVC',accuracy_score(Y_test,y_pred)]
model_res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15176/975321122.py in <module>
#       1 from sklearn.svm import SVC
#       2 model = SVC()
# ----> 3 model.fit(x_train, y_train)
#       4 y_pred = model.predict(x_test)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     167         Returns
#     168         -------
# --> 169         self : object
#     170             Fitted estimator.
#     171
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431             Whether to reset the `feature_names_in_` attribute.
#     432             If False, the input will be checked for consistency with
# --> 433             feature names of data provided when reset was last True.
#     434             .. note::
#     435                It is recommended to call `reset=True` in `fit` and in the first
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869                     unique_dtypes = set([dt.subtype.name for dt in array_orig.dtypes])
#     870                     if len(unique_dtypes) > 1:
# --> 871                         raise ValueError(
#     872                             "Pandas DataFrame with mixed sparse extension arrays "
#     873                             "generated a sparse matrix with object dtype which "
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718         Whether to raise a value error if array is not 2D.
#     719
# --> 720     allow_nd : bool, default=False
#     721         Whether to allow array.ndim > 2.
#     722
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101
#     102     X = xp.asarray(X)
# --> 103
#     104     # for object dtype data, we only check for NaNs (GH-13254)
#     105     if X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# # Using Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion = 'entropy', random_state = 7)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_scope
print("Accuracy Score:", accuracy_score(y_test, y_pred))
model_res.loc[len(model_res)] = ['DecisionTreeClassifier', accuracy_score(y_test,y_pred)]
model_res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15176/2938096980.py in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 model = DecisionTreeClassifier(criterion = 'entropy', random_state = 7)
# ----> 3 model.fit(x_train, y_train)
#       4 y_pred = model.predict(x_test)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         splitter="best",
#     902         max_depth=None,
# --> 903         min_samples_split=2,
#     904         min_samples_leaf=1,
#     905         min_weight_fraction_leaf=0.0,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     155         self.ccp_alpha = ccp_alpha
#     156
# --> 157     def get_depth(self):
#     158         """Return the depth of the decision tree.
#     159
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     428             The input samples.
#     429
# --> 430         reset : bool
#     431             Whether to reset the `feature_names_in_` attribute.
#     432             If False, the input will be checked for consistency with
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718         Whether to raise a value error if array is not 2D.
#     719
# --> 720     allow_nd : bool, default=False
#     721         Whether to allow array.ndim > 2.
#     722
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101
#     102     X = xp.asarray(X)
# --> 103
#     104     # for object dtype data, we only check for NaNs (GH-13254)
#     105     if X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %% [markdown]
# # Using GaussianNB:

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(x_train,y_train)
y_pred = model3.predict(x_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,y_pred))
model_res.loc[len(model_res)] = ['GaussianNB',accuracy_score(y_test,y_pred)]
model_res
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15176/980004685.py in <module>
# ----> 1 from sklearn.naive_bayes import GaussianNB
#       2 model3 = GaussianNB()
#       3 model3.fit(x_train,y_train)
#       4 y_pred = model3.predict(x_test)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in <module>
#      21 from scipy.special import logsumexp
#      22
# ---> 23 from .base import BaseEstimator, ClassifierMixin, _fit_context
#      24 from .preprocessing import LabelBinarizer, binarize, label_binarize
#      25 from .utils._param_validation import Hidden, Interval, StrOptions
#
# ImportError: cannot import name '_fit_context' from 'sklearn.base' (C:\Users\91790\anaconda3\lib\site-packages\sklearn\base.py)

# %% [markdown]
# # Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state = 1)
model2.fit(x_train, y_train)
y_pred = model2.predict(x_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:", accuracy_score(y_test, y_pred))
model_res.loc[len(model_res)] = ["RandomForestClassifier", accuracy_score(y_test, y_pred)]
model_res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15176/4096332004.py in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 model2 = RandomForestClassifier(random_state = 1)
# ----> 3 model2.fit(x_train, y_train)
#       4 y_pred = model2.predict(x_test)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302         indicators = Parallel(
#     303             n_jobs=self.n_jobs,
# --> 304             verbose=self.verbose,
#     305             prefer="threads",
#     306         )(
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431             Whether to reset the `feature_names_in_` attribute.
#     432             If False, the input will be checked for consistency with
# --> 433             feature names of data provided when reset was last True.
#     434             .. note::
#     435                It is recommended to call `reset=True` in `fit` and in the first
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869                     unique_dtypes = set([dt.subtype.name for dt in array_orig.dtypes])
#     870                     if len(unique_dtypes) > 1:
# --> 871                         raise ValueError(
#     872                             "Pandas DataFrame with mixed sparse extension arrays "
#     873                             "generated a sparse matrix with object dtype which "
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         @wraps(f)
#      62         def inner_f(*args, **kwargs):
# ---> 63             extra_args = len(args) - len(all_args)
#      64             if extra_args <= 0:
#      65                 return f(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718         Whether to raise a value error if array is not 2D.
#     719
# --> 720     allow_nd : bool, default=False
#     721         Whether to allow array.ndim > 2.
#     722
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101
#     102     X = xp.asarray(X)
# --> 103
#     104     # for object dtype data, we only check for NaNs (GH-13254)
#     105     if X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
''
